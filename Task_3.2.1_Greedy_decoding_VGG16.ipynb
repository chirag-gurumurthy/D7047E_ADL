# %%
from keras.applications import VGG16
from keras.models import Model

full_model = VGG16(weights='imagenet')
cnn_model = Model(inputs =full_model.input, outputs=full_model.get_layer('fc2').output)

cnn_model.trainable = False
# Out:
# 2026-05-13 17:07:20.434692: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778684840.453124 2317051 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778684840.459325 2317051 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778684840.473004 2317051 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778684840.473035 2317051 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778684840.473037 2317051 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778684840.473039 2317051 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-05-13 17:07:20.478343: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1778684847.150686 2317051 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38487 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:0e:00.0, compute capability: 8.0
# I0000 00:00:1778684847.153808 2317051 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 5883 MB memory:  -> device: 1, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:13:00.0, compute capability: 8.0
# I0000 00:00:1778684847.155516 2317051 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 21099 MB memory:  -> device: 2, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:4a:00.0, compute capability: 8.0
# I0000 00:00:1778684847.159003 2317051 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 5849 MB memory:  -> device: 3, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:50:00.0, compute capability: 8.0
# I0000 00:00:1778684847.160698 2317051 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 21121 MB memory:  -> device: 4, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:93:00.0, compute capability: 8.0
# I0000 00:00:1778684847.162393 2317051 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 20787 MB memory:  -> device: 5, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:99:00.0, compute capability: 8.0
# I0000 00:00:1778684847.164132 2317051 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:6 with 7281 MB memory:  -> device: 6, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:cb:00.0, compute capability: 8.0
# I0000 00:00:1778684847.166830 2317051 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:7 with 7187 MB memory:  -> device: 7, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:d0:00.0, compute capability: 8.0

# %%
from keras.preprocessing.image import load_img, img_to_array
from keras.applications.vgg16 import preprocess_input
import numpy as np

def preprocess_image(image_path):
    img = load_img(image_path, target_size=(224, 224))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = preprocess_input(img)
    return img

# %%
def extract_features(image_path):
    image = preprocess_image(image_path)
    features = cnn_model.predict(image, verbose=0)[0]
    return features

# %%
import os
from tqdm import tqdm
import torch

path="/home/chigurstu/projects/ADL/lab_3/flickr8k"
image_folder = os.path.join(path, "images")
image_files = os.listdir(image_folder)

image_features = {}

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device:', device)

if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))

for image_name in tqdm(image_files, desc="Extracting features"):

    image_path = os.path.join(image_folder, image_name)
    image_features[image_name] = extract_features(image_path)
# Out:
# device: cuda
# NVIDIA A100-SXM4-40GB
# Extracting features:   0%|          | 0/8091 [00:00<?, ?it/s]I0000 00:00:1778684852.885820 2323715 service.cc:152] XLA service 0x7f55e8002a30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778684852.885865 2323715 service.cc:160]   StreamExecutor device (0): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# I0000 00:00:1778684852.885868 2323715 service.cc:160]   StreamExecutor device (1): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# I0000 00:00:1778684852.885871 2323715 service.cc:160]   StreamExecutor device (2): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# I0000 00:00:1778684852.885873 2323715 service.cc:160]   StreamExecutor device (3): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# I0000 00:00:1778684852.885875 2323715 service.cc:160]   StreamExecutor device (4): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# I0000 00:00:1778684852.885878 2323715 service.cc:160]   StreamExecutor device (5): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# I0000 00:00:1778684852.885880 2323715 service.cc:160]   StreamExecutor device (6): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# I0000 00:00:1778684852.885882 2323715 service.cc:160]   StreamExecutor device (7): NVIDIA A100-SXM4-40GB, Compute Capability 8.0
# 2026-05-13 17:07:32.895924: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1778684853.003581 2323715 cuda_dnn.cc:529] Loaded cuDNN version 91700
# 2026-05-13 17:07:34.039235: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 4 bytes spill stores, 4 bytes spill loads
#
# 2026-05-13 17:07:34.095465: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 192 bytes spill stores, 192 bytes spill loads
#
# 2026-05-13 17:07:34.902354: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 5140 bytes spill stores, 5136 bytes spill loads
#
# 2026-05-13 17:07:35.166054: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3', 4392 bytes spill stores, 4392 bytes spill loads
#
# I0000 00:00:1778684856.357568 2323715 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Extracting features: 100%|██████████| 8091/8091 [14:07<00:00,  9.55it/s]

# %% [markdown]
# Image features were extracted using a pretrained VGG16 CNN with ImageNet weights. The fully connected layers were removed, and each image was represented as a 25,088‑dimensional feature vector. Features were extracted once and cached to disk to reduce computational cost during training.

# %%
import pickle

with open("flickr8k_image_features.pkl", "wb") as f:
    pickle.dump(image_features, f)

# %%
import pandas as pd

captions_path = os.path.join(path, "captions.txt")

df = pd.read_csv(captions_path)
df.head()
# Out:
#                        image  \
# 0  1000268201_693b08cb0e.jpg
# 1  1000268201_693b08cb0e.jpg
# 2  1000268201_693b08cb0e.jpg
# 3  1000268201_693b08cb0e.jpg
# 4  1000268201_693b08cb0e.jpg
#
#                                              caption
# 0  A child in a pink dress is climbing up a set o...
# 1              A girl going into a wooden building .
# 2   A little girl climbing into a wooden playhouse .
# 3  A little girl climbing the stairs to her playh...
# 4  A little girl in a pink dress going into a woo...

# %%
#basic caption cleaning function
import string

def clean_caption(caption):
    caption = caption.lower()
    caption = caption.translate(str.maketrans('', '', string.punctuation))
    caption = caption.strip()
    caption = " ".join(caption.split())
    caption = f"<start> {caption} <end>"
    return caption

# %%
#group captions by image
from collections import defaultdict

image_to_captions = defaultdict(list)

for _, row in df.iterrows():
    image = row["image"]
    caption = clean_caption(row["caption"])
    image_to_captions[image].append(caption)

# %%
set(image_to_captions.keys()) == set(image_features.keys())
# Out:
# True

# %%
missing = set(image_to_captions.keys()) - set(image_features.keys())
len(missing)
# Out:
# 0

# %%
import random

image_ids = list(image_to_captions.keys())
len(image_ids)
# Out:
# 8091

# %%
random.seed(42)
random.shuffle(image_ids)

train_ratio = 0.7
val_ratio = 0.15

total_images = len(image_ids)

train_end = int(total_images * train_ratio)
val_end = int(total_images * (train_ratio + val_ratio))

train_images = image_ids[:train_end]
val_images = image_ids[train_end:val_end]
test_images = image_ids[val_end:]

# %%
print("Train images:", len(train_images))
print("Validation images:", len(val_images))
print("Test images:", len(test_images))
# Out:
# Train images: 5663
# Validation images: 1214
# Test images: 1214

# %%
assert set(train_images).isdisjoint(val_images)
assert set(train_images).isdisjoint(test_images)
assert set(val_images).isdisjoint(test_images)

print("No image leakage across splits")
# Out:
# No image leakage across splits

# %%
#split specific caption dictionaries
train_captions = {img: image_to_captions[img] for img in train_images}
val_captions   = {img: image_to_captions[img] for img in val_images}
test_captions  = {img: image_to_captions[img] for img in test_images}

#image features with each split
train_features = {img: image_features[img] for img in train_images}
val_features   = {img: image_features[img] for img in val_images}
test_features  = {img: image_features[img] for img in test_images}

# %% [markdown]
# The Flickr8k dataset was split at the image level into training (70%), validation (15%), and testing (15%) subsets. All captions belonging to a single image were kept within the same split to prevent information leakage.

# %%
all_train_captions = []

for captions in train_captions.values():
    all_train_captions.extend(captions)

len(all_train_captions)
# Out:
# 28315

# %%
#create and fit the tokenizer
from keras.src.legacy.preprocessing.text import Tokenizer

max_vocab_size = 5000

tokenizer = Tokenizer(
    num_words=max_vocab_size,
    oov_token="<unk>"
)
tokenizer.fit_on_texts(all_train_captions)

# %%
vocab_size = len(tokenizer.word_index) + 1
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 7532

# %%
#maximum caption length
from keras.utils import pad_sequences

max_length = max(len(caption.split()) for caption in all_train_captions)
print("Max caption length:", max_length)
# Out:
# Max caption length: 38

# %%
#sequence generation function
import numpy as np
from keras.utils import to_categorical

def create_sequences_sparse(tokenizer, max_length, captions, image_feature):
    X_img, X_seq, y = [], [], []

    for caption in captions:
        seq = tokenizer.texts_to_sequences([caption])[0]

        for i in range(1, len(seq)):
            in_seq = seq[:i]
            out_word = seq[i]  # INTEGER, not one-hot

            in_seq = pad_sequences([in_seq], maxlen=max_length, padding='post')[0]

            X_img.append(image_feature)
            X_seq.append(in_seq)
            y.append(out_word)

    return np.array(X_img), np.array(X_seq), np.array(y)

# %% [markdown]
# A tokenizer is trained exclusively on the training captions to prevent information leakage. Captions were converted into sequences, and for each image–caption pair multiple training samples were generated using a next‑word prediction strategy.

# %%
X_img_train, X_seq_train, y_train = [], [], []

for img in train_images:
    img_feature = train_features[img]
    captions = train_captions[img]

    X1, X2, y = create_sequences_sparse(
        tokenizer,
        max_length,
        captions,
        img_feature
    )

    X_img_train.extend(X1)
    X_seq_train.extend(X2)
    y_train.extend(y)
    
#convert to numpy arrays
X_img_train = np.array(X_img_train)
X_seq_train = np.array(X_seq_train)
y_train = np.array(y_train)

# %%
print("Image features shape:", X_img_train.shape)
print("Caption sequences shape:", X_seq_train.shape)
print("Output words shape:", y_train.shape)
# Out:
# Image features shape: (333436, 4096)
# Caption sequences shape: (333436, 38)
# Output words shape: (333436,)

# %%
from keras.models import Model
from keras.layers import (
    Input, Dense, Embedding, LSTM, Dropout, Concatenate
)
from keras.optimizers import Adam

# %%
#image feature branch
image_input = Input(shape=(4096,), name="image_input")
image_dense = Dense(256, activation="relu")(image_input)
image_dense = Dropout(0.5)(image_dense)

# %%
#caption branch
caption_input = Input(shape=(max_length,), name="caption_input")

caption_embedding = Embedding(
    input_dim=vocab_size,
    output_dim=256,
    mask_zero=True
)(caption_input)

caption_lstm = LSTM(256)(caption_embedding)

# %%
#combine image + text (concatenation)
combined = Concatenate()([image_dense, caption_lstm])
combined = Dense(256, activation="relu")(combined)
combined = Dropout(0.5)(combined)

# %%
#output layer
output = Dense(vocab_size, activation="softmax")(combined)

#build the model
model = Model(
    inputs=[image_input, caption_input],
    outputs=output
)

# %%
#compile the model
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam'
)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ image_input         │ (None, 4096)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ caption_input       │ (None, 38)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │  1,048,832 │ image_input[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 38, 256)   │  1,928,192 │ caption_input[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal           │ (None, 38)        │          0 │ caption_input[0]… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 256)       │    525,312 │ embedding[0][0],  │
# │                     │                   │            │ not_equal[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 512)       │          0 │ dropout[0][0],    │
# │ (Concatenate)       │                   │            │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    131,328 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 7532)      │  1,935,724 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,569,388 (21.25 MB)
#  Trainable params: 5,569,388 (21.25 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# The implemented model contains two input branches: one for CNN‑extracted image features and one for caption sequences processed by an embedding layer and LSTM. The embeddings are concatenated and passed through fully connected layers to predict the next word in the caption.

# %%
#generate validation data
X_img_val, X_seq_val, y_val = [], [], []

for img in val_images:
    img_feature = val_features[img]
    captions = val_captions[img]

    X1, X2, y = create_sequences_sparse(
        tokenizer, max_length, captions, img_feature
    )

    X_img_val.extend(X1)
    X_seq_val.extend(X2)
    y_val.extend(y)

X_img_val = np.array(X_img_val)
X_seq_val = np.array(X_seq_val)
y_val = np.array(y_val)

# %%
print(X_img_val.shape)
print(X_seq_val.shape)
print(y_val.shape)
# Out:
# (71509, 4096)
# (71509, 38)
# (71509,)

# %%
def data_generator(images, captions_dict, features_dict,
                   tokenizer, max_length, batch_size=64):
    while True:
        X_img, X_seq, y = [], [], []

        for img in images:
            img_feature = features_dict[img]
            captions = captions_dict[img]

            for caption in captions:
                seq = tokenizer.texts_to_sequences([caption])[0]

                for i in range(1, len(seq)):
                    in_seq = seq[:i]
                    out_word = seq[i]

                    in_seq = pad_sequences([in_seq], maxlen=max_length, padding='post')[0]

                    X_img.append(img_feature)
                    X_seq.append(in_seq)
                    y.append(out_word)

                    if len(X_img) == batch_size:
                        yield (
                            (np.array(X_img), np.array(X_seq)),
                            np.array(y)
                        )
                        X_img, X_seq, y = [], [], []

# %%
steps_per_epoch = len(train_images) * 5 // 64
val_steps = len(val_images) * 5 // 64

history = model.fit(
    data_generator(
        train_images, train_captions, train_features,
        tokenizer, max_length
    ),
    validation_data=data_generator(
        val_images, val_captions, val_features,
        tokenizer, max_length
    ),
    epochs=50,
    steps_per_epoch=steps_per_epoch,
    validation_steps=val_steps
)
# Out:
# Epoch 1/50
# /home/chigurstu/envs/yolo_26/lib/python3.9/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['image_input', 'caption_input']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.1642 - val_loss: 4.7795
# Epoch 2/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.7860 - val_loss: 4.3974
# Epoch 3/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 4.5023 - val_loss: 4.1924
# Epoch 4/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 4.3377 - val_loss: 4.0379
# Epoch 5/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 4.2603 - val_loss: 3.9668
# Epoch 6/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.0681 - val_loss: 3.9507
# Epoch 7/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 4.0746 - val_loss: 3.8445
# Epoch 8/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 4.0201 - val_loss: 3.7662
# Epoch 9/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 3.9961 - val_loss: 3.7101
# Epoch 10/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.8927 - val_loss: 3.9027
# Epoch 11/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.8856 - val_loss: 3.7517
# Epoch 12/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.9397 - val_loss: 3.6878
# Epoch 13/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.8558 - val_loss: 3.5560
# Epoch 14/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.8269 - val_loss: 3.5174
# Epoch 15/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.7495 - val_loss: 3.6342
# Epoch 16/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 3.6854 - val_loss: 3.4990
# Epoch 17/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.5825 - val_loss: 3.4722
# Epoch 18/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 3.5975 - val_loss: 3.5510
# Epoch 19/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.6556 - val_loss: 3.4843
# Epoch 20/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.6047 - val_loss: 3.4754
# Epoch 21/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.5263 - val_loss: 3.4287
# Epoch 22/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 3.5479 - val_loss: 3.6433
# Epoch 23/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 3.5172 - val_loss: 3.4896
# Epoch 24/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.6056 - val_loss: 3.5007
# Epoch 25/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.4931 - val_loss: 3.4326
# Epoch 26/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.5736 - val_loss: 3.3466
# Epoch 27/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 3.4852 - val_loss: 3.4983
# Epoch 28/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.4024 - val_loss: 3.3351
# Epoch 29/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.3985 - val_loss: 3.3132
# Epoch 30/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.4066 - val_loss: 3.4856
# Epoch 31/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.4527 - val_loss: 3.3874
# Epoch 32/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.4140 - val_loss: 3.3296
# Epoch 33/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 3.3640 - val_loss: 3.4095
# Epoch 34/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 3.3335 - val_loss: 3.5786
# Epoch 35/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.3844 - val_loss: 3.4371
# Epoch 36/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 3.3979 - val_loss: 3.3541
# Epoch 37/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.3554 - val_loss: 3.3720
# Epoch 38/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.3990 - val_loss: 3.3095
# Epoch 39/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.3746 - val_loss: 3.4574
# Epoch 40/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.2991 - val_loss: 3.3259
# Epoch 41/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.2591 - val_loss: 3.1997
# Epoch 42/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 3.2223 - val_loss: 3.5095
# Epoch 43/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 3.2868 - val_loss: 3.3363
# Epoch 44/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.3515 - val_loss: 3.2787
# Epoch 45/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.2080 - val_loss: 3.4006
# Epoch 46/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.2145 - val_loss: 3.4955
# Epoch 47/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 3.2762 - val_loss: 3.4365
# Epoch 48/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.2659 - val_loss: 3.2952
# Epoch 49/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 3.2710 - val_loss: 3.3260
# Epoch 50/50
# 442/442 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 3.2334 - val_loss: 3.3120

# %% [markdown]
# The model was trained for 10 epochs using a generator‑based strategy with sparse categorical cross‑entropy. Validation loss was computed at the end of each epoch and showed steady convergence without significant overfitting.

# %%
index_to_word = {index: word for word, index in tokenizer.word_index.items()}

# %%
#caption generation function
from keras.preprocessing.sequence import pad_sequences
import numpy as np

def generate_caption(model, image_feature, tokenizer, max_length):
    caption = "<start>"

    for _ in range(max_length):
        sequence = tokenizer.texts_to_sequences([caption])[0]
        sequence = pad_sequences([sequence], maxlen=max_length, padding='post')

        y_pred = model.predict([image_feature.reshape(1, -1), sequence], verbose=0)
        predicted_word_index = np.argmax(y_pred)

        word = index_to_word.get(predicted_word_index, None)

        if word is None:
            break

        caption += " " + word

        if word == "<end>" or word == "end":
            break

    return caption

# %%
#generate captions for test images
sample_test_images = list(test_features.keys())[:5]

for img in sample_test_images:
    feature = test_features[img]
    generated_caption = generate_caption(model, feature, tokenizer, max_length)

    print(f"Image: {img}")
    print("Generated Caption:", generated_caption)
    print("Ground Truth Captions:")
    for cap in test_captions[img]:
        print(" -", cap)
    print("-" * 60)
# Out:
# Image: 2089542487_b4c1ee7025.jpg
# Generated Caption: <start> a man in a red shirt is standing on a bench end
# Ground Truth Captions:
#  - <start> a hiker is ready to take on a rugged outdoor trail <end>
#  - <start> a lone hiker on a dirt hiking trail with a hat and sunglasses on with trees in the background <end>
#  - <start> a man in shorts is hiking in a dry region <end>
#  - <start> a man stops for a picture with the scenery during his hike <end>
#  - <start> the man is posing for a picture in the desert wearing a green shirt and hat and holding a metal detector <end>
# ------------------------------------------------------------
# Image: 2477121456_1ac5c6d3e4.jpg
# Generated Caption: <start> a man in a red shirt is standing on a bench end
# Ground Truth Captions:
#  - <start> a black dog plays in the water <end>
#  - <start> a black dog s head rises above some water <end>
#  - <start> a black dog splashes in the water <end>
#  - <start> drenched black labrador in the water <end>
#  - <start> the black dog s head is poking up out of the water <end>
# ------------------------------------------------------------
# Image: 1772859261_236c09b861.jpg
# Generated Caption: <start> a man in a red shirt is standing on a bench end
# Ground Truth Captions:
#  - <start> a black and white dog plays in the water <end>
#  - <start> a black and white dog walking in shallow water <end>
#  - <start> a dog splashes through the water <end>
#  - <start> a dog swims <end>
#  - <start> black and white dog wearing a harness walking through water <end>
# ------------------------------------------------------------
# Image: 78984436_ad96eaa802.jpg
# Generated Caption: <start> a man in a red shirt is standing on a bench end
# Ground Truth Captions:
#  - <start> a german shepherd chases another with a stick in his mouth <end>
#  - <start> a german shepherd dog following another german shepherd who has a stick in its mouth <end>
#  - <start> a german shepherd dog is running behind another german shepherd dog that is carrying a stick in its mouth <end>
#  - <start> two german shepherd dogs are running with an object in one s mouth <end>
#  - <start> two german shepherds playing with a stick <end>
# ------------------------------------------------------------
# Image: 3227499174_07feb26337.jpg
# Generated Caption: <start> a man in a red shirt is standing on a bench end
# Ground Truth Captions:
#  - <start> a bride and groom stand in front of a church display while looking at one another <end>
#  - <start> a man and wife stand at the alter as they get married <end>
#  - <start> bride and groom standing in a church surrounded by flowers <end>
#  - <start> newlyweds smile and pose for a picture after their ceremony <end>
#  - <start> two people are getting married in a church <end>
# ------------------------------------------------------------

# %%
import nltk
from nltk.translate.bleu_score import corpus_bleu, SmoothingFunction
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/chigurstu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#clean captions for BLEU
def clean_caption_for_bleu(caption):
    caption = caption.replace("<start>", "").replace("<end>", "")
    caption = caption.strip()
    return caption.split()

# %%
#generate predictions on test images
references = []
hypotheses = []

smoothie = SmoothingFunction().method4

for img in test_images:
    # Generate caption
    feature = test_features[img]
    generated = generate_caption(model, feature, tokenizer, max_length)

    # Prepare ground truth captions
    gt_captions = test_captions[img]
    gt_tokens = [clean_caption_for_bleu(cap) for cap in gt_captions]

    # Prepare generated caption
    gen_tokens = clean_caption_for_bleu(generated)

    references.append(gt_tokens)
    hypotheses.append(gen_tokens)

# %%
#BLEU‑1 (Unigram)
bleu_1 = corpus_bleu(
    references,
    hypotheses,
    weights=(1.0, 0, 0, 0),
    smoothing_function=smoothie
)

# %%
#BLEU‑4 (Up to 4‑grams)
bleu_4 = corpus_bleu(
    references,
    hypotheses,
    weights=(0.25, 0.25, 0.25, 0.25),
    smoothing_function=smoothie
)

# %%
print(f"BLEU-1 score: {bleu_1:.4f}")
print(f"BLEU-4 score: {bleu_4:.4f}")
# Out:
# BLEU-1 score: 0.4387
# BLEU-4 score: 0.0725

# %% [markdown]
# The trained image‑captioning model was evaluated on the unseen test set using BLEU scores. The model achieved a BLEU‑1 score of 0.4387 and a BLEU‑4 score of 0.0725. These results are consistent with baseline CNN–LSTM image captioning models on the Flickr8k dataset and indicate that the model successfully captures both object‑level and partial phrase‑level information despite the absence of an attention mechanism.

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os

# %%
#caption cleaning for display
def clean_caption_display(caption):
    caption = caption.replace("<start>", "")
    caption = caption.replace("<end>", "")
    caption = caption.replace("end", "")
    return caption.strip()

# %%
def visualize_caption(image_name, image_path,
                      model, tokenizer, max_length,
                      test_features, test_captions):
    # Load image
    img = Image.open(os.path.join(image_path, image_name))

    # Generate caption
    feature = test_features[image_name]
    generated = generate_caption(model, feature, tokenizer, max_length)
    generated = clean_caption_display(generated)

    # Prepare ground truth
    gt_captions = [
        clean_caption_display(cap)
        for cap in test_captions[image_name]
    ]

    # Plot
    plt.figure(figsize=(8, 8))
    plt.imshow(img)
    plt.axis("off")

    title_text = "Generated Caption:\n"
    title_text += generated + "\n\nGround Truth Captions:\n"
    for cap in gt_captions:
        title_text += "- " + cap + "\n"

    plt.title(title_text, fontsize=10, loc="left")
    plt.show()

# %%
image_path = os.path.join(path, "images")

sample_images = test_images[:5]

for img_name in sample_images:
    visualize_caption(
        img_name,
        image_path,
        model,
        tokenizer,
        max_length,
        test_features,
        test_captions
    )
